# %% [markdown]
# # Plotting Function

# %%
import matplotlib.pyplot as plt

def plot_missing_count(labels, missing_percentages, colors, figsize=(10, 6)):

    # Create histogram

    fig = plt.gcf().set_size_inches(figsize)
    plt.barh(labels, missing_percentages, color=colors)
    
    plt.rcParams['mathtext.fontset'] = 'cm'
    plt.rcParams["font.family"] = "serif"
    plt.rcParams["font.serif"] = ["Times New Roman"
                                                ] + plt.rcParams["font.serif"]
    plt.rcParams['font.size'] = 13
    plt.rcParams['figure.dpi'] = 600

    # Set labels and title
    plt.xlabel('% Missing Values', fontsize=14)
    # set font size for tick labels
    plt.tick_params(axis='x', labelsize=18)
    plt.tick_params(axis='y', labelsize=18)
    # Display the histogram
    plt.show()

# %% [markdown]
# # Case D1

# %%
# % of missing values in VW: 0.00%
# % of missing values in FR: 1.37%
# % of missing values in CNaCl: 0.00%
# % of missing values in SSA: 0.00%
# % of missing values in PV: 1.72%
# % of missing values in Psave: 0.34%
# % of missing values in PVmicro: 54.89%
# % of missing values in ID/IG: 31.22%
# % of missing values in N: 26.93%
# % of missing values in O: 29.50%
# % of missing values in EC: 0.00%

# %%
#labels_new = ['PVmicro', 'ID/IG', 'N', 'O', 'PV', 'FR', 'Psave', 'VW', 'CONC', 'SSA', 'EC']

labels_new = [
    r'$\rm PVmicro$',
    r'$\rm ID/IG$',
    r'$\rm \%N$',
    r'$\rm \%O$',
    r'$\rm PV$',
    r'$\rm FR$',
    r'$\rm Psave$',
    r'$\rm VW$',
    r'$\rm CONC$',
    r'$\rm SSA$',
    r'$\rm EC$']
missing_percentages_new = [54.89, 31.22, 26.93, 29.50, 1.72, 1.37, 0.34, 0.00, 0.00, 0.00, 0.00]
colors_new = ['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightsteelblue', 'plum', 'lightcyan', 'palegoldenrod', 'lightpink', 'mediumaquamarine', 'powderblue']

# Create histogram
plot_missing_count(labels_new, missing_percentages_new, colors_new, figsize=(3, 4))

# %% [markdown]
# # Case D2

# %%
# ['SA', 'DG', '%N', '%O', '%S', 'CD', 'CONC', 'CAP']
labels = [
    r'$\rm SSA$',
    r'$\rm DG$',
    r'$\rm \%N$',
    r'$\rm \%O$',
    r'$\rm \%S$',
    r'$\rm CD$',
    r'$\rm CONC$',
    r'$\rm CAP$']
missing_percentages = [0.00, 12.74, 35.16, 12.58, 61.94, 0.00, 0.00, 0.00]
colors = ['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightsteelblue', 'plum', 'lightcyan', 'palegoldenrod']


plot_missing_count(labels, missing_percentages, colors, figsize=(3, 4))
