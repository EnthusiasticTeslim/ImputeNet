# %% [markdown]
# # Import Library

# %%
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# cwd
print(f'Current working directory: {os.getcwd()}')
# change directory
os.chdir('../')
print(f'New working directory: {os.getcwd()}')
# Out:
# /var/folders/83/j83q5_mj11956_7k9tnld0ym0000gn/T/ipykernel_47148/3146130768.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# Current working directory: /Users/gbemidebe/Documents/GitHub/CDImodeling/notebooks
# New working directory: /Users/gbemidebe/Documents/GitHub/CDImodeling

# %%
from cdi.plotters import Plotters

plotter = Plotters()
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %% [markdown]
# # Load Data

# %% [markdown]
# SA --> surface area
# DG --> defect ratio
# %N --> percent nitrogen
# %O --> percent oxygen
# %S --> percent sulphur
# CD --> current density
# CONC --> concentration of electrolyte
# CAP --> specific capacitance

# %%
import pandas as pd

desired_columns = ['SA', 'DG', '%N', '%O', '%S', 'CD', 'CONC', 'CAP']

data = pd.read_csv('data/specific_capacitance_data.csv')
data = data[desired_columns]
print(data.shape)
data.head()
# Out:
# (620, 8)
#        SA    DG  %N   %O  %S    CD  CONC     CAP
# 0  1122.5  0.85 NaN  5.7 NaN   0.5   6.0  240.63
# 1  1122.5  0.85 NaN  5.7 NaN   1.0   6.0  228.13
# 2  1122.5  0.85 NaN  5.7 NaN   2.0   6.0  225.00
# 3  1122.5  0.85 NaN  5.7 NaN   5.0   6.0  215.63
# 4  1122.5  0.85 NaN  5.7 NaN  10.0   6.0  206.25

# %%
data.isna().sum()
# Out:
# SA        0
# DG       79
# %N      218
# %O       78
# %S      384
# CD        0
# CONC      0
# CAP       0
# dtype: int64

# %%
for col in data.columns:
    print(f'% of missing values in {col}: {data[col].isna().sum()/len(data)*100:.2f}%')
# Out:
# % of missing values in SA: 0.00%
# % of missing values in DG: 12.74%
# % of missing values in %N: 35.16%
# % of missing values in %O: 12.58%
# % of missing values in %S: 61.94%
# % of missing values in CD: 0.00%
# % of missing values in CONC: 0.00%
# % of missing values in CAP: 0.00%

# %%
plotter.plot_heat_map(data=data, label = r'$ \rm Actual$', property = 'original',
                    fig_size = (7, 5), save_fig = False)

# %%
# drop missing values
clean_data = data.dropna()
print(clean_data.shape)
clean_data.head()
# Out:
# (159, 8)
#         SA    DG    %N     %O    %S    CD  CONC    CAP
# 152  308.8  1.01  1.46  11.94  1.14   0.5   6.0  378.0
# 153  308.8  1.01  1.46  11.94  1.14   1.0   6.0  352.0
# 154  308.8  1.01  1.46  11.94  1.14   2.0   6.0  325.0
# 155  308.8  1.01  1.46  11.94  1.14   5.0   6.0  308.0
# 156  308.8  1.01  1.46  11.94  1.14  10.0   6.0  292.0

# %% [markdown]
# # Imputation

# %%
import pandas as pd
import numpy as np
from loguru import logger
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import BayesianRidge
from sklearn.model_selection import train_test_split
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
# from xgboost import XGBRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.impute import KNNImputer

from cdi.dataPreprocessing import Imputation

# %%
# create artificial missing values
def introduce_missing_values(dataframe, missing_fraction):
    mask = np.random.rand(*dataframe.shape) < missing_fraction
    dataframe[mask] = np.nan
    return dataframe

# Function to introduce artificial missing values in specific columns
def introduce_missing_values_in_columns(dataframe, columns, missing_fraction):
    for col in columns:
        mask = np.random.rand(dataframe[col].shape[0]) < missing_fraction
        dataframe.loc[mask, col] = np.nan
    return dataframe

# %%
idx = 'SA' #np.random.choice(clean_data.columns) #'SA'

# %%
# set random state to reproduce the same results
random_seed = 54

np.random.seed(random_seed)
random.seed(random_seed)

# %% [markdown]
# ## Case 1: 20%

# %%
missing_fraction = 0.20 # 0.20, 0.50, 0.70
clean_data_with_NaN = introduce_missing_values_in_columns(clean_data.copy(), [idx], missing_fraction)
clean_data_with_NaN.head()
# Out:
#         SA    DG    %N     %O    %S    CD  CONC    CAP
# 152  308.8  1.01  1.46  11.94  1.14   0.5   6.0  378.0
# 153  308.8  1.01  1.46  11.94  1.14   1.0   6.0  352.0
# 154    NaN  1.01  1.46  11.94  1.14   2.0   6.0  325.0
# 155  308.8  1.01  1.46  11.94  1.14   5.0   6.0  308.0
# 156    NaN  1.01  1.46  11.94  1.14  10.0   6.0  292.0

# %%
for col in clean_data_with_NaN.columns:
    print(f'% of missing values in {col}: {clean_data_with_NaN[col].isna().sum()/len(clean_data_with_NaN)*100:.2f}%')
# Out:
# % of missing values in SA: 22.01%
# % of missing values in DG: 0.00%
# % of missing values in %N: 0.00%
# % of missing values in %O: 0.00%
# % of missing values in %S: 0.00%
# % of missing values in CD: 0.00%
# % of missing values in CONC: 0.00%
# % of missing values in CAP: 0.00%

# %% [markdown]
# #### KNN

# %%
method = 'KNN'
model = KNNImputer(n_neighbors=5, weights="uniform")


IMPUTER = Imputation(data=clean_data_with_NaN, columns=desired_columns, model=model, method=method)

df_imputed = IMPUTER.impute_data(split_data=False)
# Out:
# 2024-02-15 11:50:20.273 | INFO     | cdi.dataPreprocessing:impute:100 - Database path:         SA    DG    %N     %O    %S    CD  CONC    CAP
# 152  308.8  1.01  1.46  11.94  1.14   0.5   6.0  378.0
# 153  308.8  1.01  1.46  11.94  1.14   1.0   6.0  352.0
# 154    NaN  1.01  1.46  11.94  1.14   2.0   6.0  325.0
# 155  308.8  1.01  1.46  11.94  1.14   5.0   6.0  308.0
# 156    NaN  1.01  1.46  11.94  1.14  10.0   6.0  292.0
# 2024-02-15 11:50:20.274 | INFO     | cdi.dataPreprocessing:impute:101 - ML method: KNN
#
# 2024-02-15 11:50:20.275 | INFO     | cdi.dataPreprocessing:impute:103 - Number of data points: 159
# 2024-02-15 11:50:20.275 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "SA": 35
# 2024-02-15 11:50:20.275 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "DG": 0
# 2024-02-15 11:50:20.276 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%N": 0
# 2024-02-15 11:50:20.276 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%O": 0
# 2024-02-15 11:50:20.277 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%S": 0
# 2024-02-15 11:50:20.277 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CD": 0
# 2024-02-15 11:50:20.278 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CONC": 0
# 2024-02-15 11:50:20.278 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CAP": 0
# 2024-02-15 11:50:20.281 | SUCCESS  | cdi.dataPreprocessing:impute:120 - Final Data shape is (159, 8).
# 2024-02-15 11:50:20.281 | SUCCESS  | cdi.dataPreprocessing:impute:121 - Imputation completed using KNN model.

# %%
# check if the imputed data is the same as the original data
# plot distribution of the original and imputed data

plotter.plot_kde(
                data = [clean_data[idx].values, df_imputed[idx].values],
                labels = [r'$ \rm Original$', r'$ \rm Imputed$'],
                colors = ['C10', 'C1'],
                property = idx,
                fig_size=(3, 2))

# %%
# crossplot
plotter.plot_cross_plot(
                        x = clean_data[idx].values,
                        y = df_imputed[idx].values,
                        x_label = r'$ \rm Original$',
                        y_label = r'$ \rm Imputed$',
                        property = idx,
                        fig_size=(3, 2))

# %%
# performance metrics
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score
print(f'IDX {idx}')
print(f'RMSE: {root_mean_squared_error(clean_data[idx].values, df_imputed[idx].values):.2f}')
print(f'MAE: {mean_absolute_error(clean_data[idx].values, df_imputed[idx].values):.2f}')
print(f'R2: {r2_score(clean_data[idx].values, df_imputed[idx].values):.2f}')
# Out:
# IDX SA
# RMSE: 166.05
# MAE: 48.36
# R2: 0.87

# %% [markdown]
# #### Extra Tree Regressor

# %%
method = 'ExtraTreesRegressor'
model = IterativeImputer(estimator=ExtraTreesRegressor(n_estimators=20),
                                 random_state=0,
                                 max_iter=500)

IMPUTER = Imputation(data=clean_data_with_NaN, columns=desired_columns, model=model, method=method)

df_imputed = IMPUTER.impute_data(split_data=False)
# Out:
# 2024-02-15 11:50:20.691 | INFO     | cdi.dataPreprocessing:impute:100 - Database path:         SA    DG    %N     %O    %S    CD  CONC    CAP
# 152  308.8  1.01  1.46  11.94  1.14   0.5   6.0  378.0
# 153  308.8  1.01  1.46  11.94  1.14   1.0   6.0  352.0
# 154    NaN  1.01  1.46  11.94  1.14   2.0   6.0  325.0
# 155  308.8  1.01  1.46  11.94  1.14   5.0   6.0  308.0
# 156    NaN  1.01  1.46  11.94  1.14  10.0   6.0  292.0
# 2024-02-15 11:50:20.691 | INFO     | cdi.dataPreprocessing:impute:101 - ML method: ExtraTreesRegressor
#
# 2024-02-15 11:50:20.692 | INFO     | cdi.dataPreprocessing:impute:103 - Number of data points: 159
# 2024-02-15 11:50:20.692 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "SA": 35
# 2024-02-15 11:50:20.693 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "DG": 0
# 2024-02-15 11:50:20.694 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%N": 0
# 2024-02-15 11:50:20.694 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%O": 0
# 2024-02-15 11:50:20.695 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%S": 0
# 2024-02-15 11:50:20.695 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CD": 0
# 2024-02-15 11:50:20.695 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CONC": 0
# 2024-02-15 11:50:20.695 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CAP": 0
# [IterativeImputer] Early stopping criterion not reached.
# 2024-02-15 11:50:47.941 | SUCCESS  | cdi.dataPreprocessing:impute:120 - Final Data shape is (159, 8).
# 2024-02-15 11:50:47.942 | SUCCESS  | cdi.dataPreprocessing:impute:121 - Imputation completed using ExtraTreesRegressor model.

# %%
# check if the imputed data is the same as the original data
# plot distribution of the original and imputed data

plotter.plot_kde(
                data = [clean_data[idx].values, df_imputed[idx].values],
                labels = [r'$ \rm Original$', r'$ \rm Imputed$'],
                colors = ['C10', 'C1'],
                property = idx,
                fig_size=(3, 2))

# %%
# # plt crossplot
plotter.plot_cross_plot(
                        x = clean_data[idx].values,
                        y = df_imputed[idx].values,
                        x_label = r'$ \rm Original$',
                        y_label = r'$ \rm Imputed$',
                        property = idx,
                        fig_size=(3, 2))

# %%
# performance metrics
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score
print(f'IDX {idx}')
print(f'RMSE: {root_mean_squared_error(clean_data[idx].values, df_imputed[idx].values):.2f}')
print(f'MAE: {mean_absolute_error(clean_data[idx].values, df_imputed[idx].values):.2f}')
print(f'R2: {r2_score(clean_data[idx].values, df_imputed[idx].values):.2f}')
# Out:
# IDX SA
# RMSE: 9.92
# MAE: 1.74
# R2: 1.00

# %% [markdown]
# ## Case 2: 50%

# %%
missing_fraction = 0.50 # 0.20, 0.50, 0.70
clean_data_with_NaN = introduce_missing_values_in_columns(clean_data.copy(), [idx], missing_fraction)
clean_data_with_NaN.head()
# Out:
#         SA    DG    %N     %O    %S    CD  CONC    CAP
# 152    NaN  1.01  1.46  11.94  1.14   0.5   6.0  378.0
# 153    NaN  1.01  1.46  11.94  1.14   1.0   6.0  352.0
# 154  308.8  1.01  1.46  11.94  1.14   2.0   6.0  325.0
# 155    NaN  1.01  1.46  11.94  1.14   5.0   6.0  308.0
# 156  308.8  1.01  1.46  11.94  1.14  10.0   6.0  292.0

# %%
for col in clean_data_with_NaN.columns:
    print(f'% of missing values in {col}: {clean_data_with_NaN[col].isna().sum()/len(clean_data_with_NaN)*100:.2f}%')
# Out:
# % of missing values in SA: 49.06%
# % of missing values in DG: 0.00%
# % of missing values in %N: 0.00%
# % of missing values in %O: 0.00%
# % of missing values in %S: 0.00%
# % of missing values in CD: 0.00%
# % of missing values in CONC: 0.00%
# % of missing values in CAP: 0.00%

# %% [markdown]
# #### KNN

# %%
method = 'KNN'
model = KNNImputer(n_neighbors=5, weights="uniform")


IMPUTER = Imputation(data=clean_data_with_NaN, columns=desired_columns, model=model, method=method)

df_imputed = IMPUTER.impute_data(split_data=False)
# Out:
# 2024-02-15 11:50:48.625 | INFO     | cdi.dataPreprocessing:impute:100 - Database path:         SA    DG    %N     %O    %S    CD  CONC    CAP
# 152    NaN  1.01  1.46  11.94  1.14   0.5   6.0  378.0
# 153    NaN  1.01  1.46  11.94  1.14   1.0   6.0  352.0
# 154  308.8  1.01  1.46  11.94  1.14   2.0   6.0  325.0
# 155    NaN  1.01  1.46  11.94  1.14   5.0   6.0  308.0
# 156  308.8  1.01  1.46  11.94  1.14  10.0   6.0  292.0
# 2024-02-15 11:50:48.626 | INFO     | cdi.dataPreprocessing:impute:101 - ML method: KNN
#
# 2024-02-15 11:50:48.626 | INFO     | cdi.dataPreprocessing:impute:103 - Number of data points: 159
# 2024-02-15 11:50:48.627 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "SA": 78
# 2024-02-15 11:50:48.627 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "DG": 0
# 2024-02-15 11:50:48.628 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%N": 0
# 2024-02-15 11:50:48.629 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%O": 0
# 2024-02-15 11:50:48.629 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%S": 0
# 2024-02-15 11:50:48.629 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CD": 0
# 2024-02-15 11:50:48.629 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CONC": 0
# 2024-02-15 11:50:48.630 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CAP": 0
# 2024-02-15 11:50:48.633 | SUCCESS  | cdi.dataPreprocessing:impute:120 - Final Data shape is (159, 8).
# 2024-02-15 11:50:48.633 | SUCCESS  | cdi.dataPreprocessing:impute:121 - Imputation completed using KNN model.

# %%
# check if the imputed data is the same as the original data
# plot distribution of the original and imputed data

plotter.plot_kde(
                data = [clean_data[idx].values, df_imputed[idx].values],
                labels = [r'$ \rm Original$', r'$ \rm Imputed$'],
                colors = ['C10', 'C1'],
                property = idx,
                fig_size=(3, 2))

# %%
# crossplot
plotter.plot_cross_plot(
                        x = clean_data[idx].values,
                        y = df_imputed[idx].values,
                        x_label = r'$ \rm Original$',
                        y_label = r'$ \rm Imputed$',
                        property = idx,
                        fig_size=(3, 2))

# %%
# performance metrics
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score
print(f'IDX {idx}')
print(f'RMSE: {root_mean_squared_error(clean_data[idx].values, df_imputed[idx].values):.2f}')
print(f'MAE: {mean_absolute_error(clean_data[idx].values, df_imputed[idx].values):.2f}')
print(f'R2: {r2_score(clean_data[idx].values, df_imputed[idx].values):.2f}')
# Out:
# IDX SA
# RMSE: 381.24
# MAE: 161.44
# R2: 0.30

# %% [markdown]
# #### Extra Tree Regressor

# %%
method = 'ExtraTreesRegressor'
model = IterativeImputer(estimator=ExtraTreesRegressor(n_estimators=20),
                                 random_state=0,
                                 max_iter=500)

IMPUTER = Imputation(data=clean_data_with_NaN, columns=desired_columns, model=model, method=method)

df_imputed = IMPUTER.impute_data(split_data=False)
# Out:
# 2024-02-15 11:50:49.006 | INFO     | cdi.dataPreprocessing:impute:100 - Database path:         SA    DG    %N     %O    %S    CD  CONC    CAP
# 152    NaN  1.01  1.46  11.94  1.14   0.5   6.0  378.0
# 153    NaN  1.01  1.46  11.94  1.14   1.0   6.0  352.0
# 154  308.8  1.01  1.46  11.94  1.14   2.0   6.0  325.0
# 155    NaN  1.01  1.46  11.94  1.14   5.0   6.0  308.0
# 156  308.8  1.01  1.46  11.94  1.14  10.0   6.0  292.0
# 2024-02-15 11:50:49.007 | INFO     | cdi.dataPreprocessing:impute:101 - ML method: ExtraTreesRegressor
#
# 2024-02-15 11:50:49.008 | INFO     | cdi.dataPreprocessing:impute:103 - Number of data points: 159
# 2024-02-15 11:50:49.009 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "SA": 78
# 2024-02-15 11:50:49.010 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "DG": 0
# 2024-02-15 11:50:49.011 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%N": 0
# 2024-02-15 11:50:49.012 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%O": 0
# 2024-02-15 11:50:49.012 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%S": 0
# 2024-02-15 11:50:49.013 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CD": 0
# 2024-02-15 11:50:49.013 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CONC": 0
# 2024-02-15 11:50:49.014 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CAP": 0
# [IterativeImputer] Early stopping criterion not reached.
# 2024-02-15 11:51:15.000 | SUCCESS  | cdi.dataPreprocessing:impute:120 - Final Data shape is (159, 8).
# 2024-02-15 11:51:15.000 | SUCCESS  | cdi.dataPreprocessing:impute:121 - Imputation completed using ExtraTreesRegressor model.

# %%
# check if the imputed data is the same as the original data
# plot distribution of the original and imputed data

plotter.plot_kde(
                data = [clean_data[idx].values, df_imputed[idx].values],
                labels = [r'$ \rm Original$', r'$ \rm Imputed$'],
                colors = ['C10', 'C1'],
                property = idx,
                fig_size=(3, 2))

# %%
# # plt crossplot
plotter.plot_cross_plot(
                        x = clean_data[idx].values,
                        y = df_imputed[idx].values,
                        x_label = r'$ \rm Original$',
                        y_label = r'$ \rm Imputed$',
                        property = idx,
                        fig_size=(3, 2))

# %%
# performance metrics
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score
print(f'IDX {idx}')
print(f'RMSE: {root_mean_squared_error(clean_data[idx].values, df_imputed[idx].values):.2f}')
print(f'MAE: {mean_absolute_error(clean_data[idx].values, df_imputed[idx].values):.2f}')
print(f'R2: {r2_score(clean_data[idx].values, df_imputed[idx].values):.2f}')
# Out:
# IDX SA
# RMSE: 62.70
# MAE: 19.83
# R2: 0.98

# %% [markdown]
# ## Case 3: 70%

# %%
missing_fraction = 0.70 # 0.20, 0.50, 0.70
clean_data_with_NaN = introduce_missing_values_in_columns(clean_data.copy(), [idx], missing_fraction)
clean_data_with_NaN.head()
# Out:
#         SA    DG    %N     %O    %S    CD  CONC    CAP
# 152    NaN  1.01  1.46  11.94  1.14   0.5   6.0  378.0
# 153  308.8  1.01  1.46  11.94  1.14   1.0   6.0  352.0
# 154    NaN  1.01  1.46  11.94  1.14   2.0   6.0  325.0
# 155  308.8  1.01  1.46  11.94  1.14   5.0   6.0  308.0
# 156    NaN  1.01  1.46  11.94  1.14  10.0   6.0  292.0

# %%
for col in clean_data_with_NaN.columns:
    print(f'% of missing values in {col}: {clean_data_with_NaN[col].isna().sum()/len(clean_data_with_NaN)*100:.2f}%')
# Out:
# % of missing values in SA: 67.30%
# % of missing values in DG: 0.00%
# % of missing values in %N: 0.00%
# % of missing values in %O: 0.00%
# % of missing values in %S: 0.00%
# % of missing values in CD: 0.00%
# % of missing values in CONC: 0.00%
# % of missing values in CAP: 0.00%

# %% [markdown]
# #### KNN

# %%
method = 'KNN'
model = KNNImputer(n_neighbors=5, weights="uniform")


IMPUTER = Imputation(data=clean_data_with_NaN, columns=desired_columns, model=model, method=method)

df_imputed = IMPUTER.impute_data(split_data=False)
# Out:
# 2024-02-15 11:51:15.586 | INFO     | cdi.dataPreprocessing:impute:100 - Database path:         SA    DG    %N     %O    %S    CD  CONC    CAP
# 152    NaN  1.01  1.46  11.94  1.14   0.5   6.0  378.0
# 153  308.8  1.01  1.46  11.94  1.14   1.0   6.0  352.0
# 154    NaN  1.01  1.46  11.94  1.14   2.0   6.0  325.0
# 155  308.8  1.01  1.46  11.94  1.14   5.0   6.0  308.0
# 156    NaN  1.01  1.46  11.94  1.14  10.0   6.0  292.0
# 2024-02-15 11:51:15.587 | INFO     | cdi.dataPreprocessing:impute:101 - ML method: KNN
#
# 2024-02-15 11:51:15.587 | INFO     | cdi.dataPreprocessing:impute:103 - Number of data points: 159
# 2024-02-15 11:51:15.588 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "SA": 107
# 2024-02-15 11:51:15.588 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "DG": 0
# 2024-02-15 11:51:15.589 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%N": 0
# 2024-02-15 11:51:15.589 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%O": 0
# 2024-02-15 11:51:15.589 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%S": 0
# 2024-02-15 11:51:15.589 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CD": 0
# 2024-02-15 11:51:15.590 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CONC": 0
# 2024-02-15 11:51:15.590 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CAP": 0
# 2024-02-15 11:51:15.593 | SUCCESS  | cdi.dataPreprocessing:impute:120 - Final Data shape is (159, 8).
# 2024-02-15 11:51:15.594 | SUCCESS  | cdi.dataPreprocessing:impute:121 - Imputation completed using KNN model.

# %%
# check if the imputed data is the same as the original data
# plot distribution of the original and imputed data

plotter.plot_kde(
                data = [clean_data[idx].values, df_imputed[idx].values],
                labels = [r'$ \rm Original$', r'$ \rm Imputed$'],
                colors = ['C10', 'C1'],
                property = idx,
                fig_size=(3, 2))

# %%
# crossplot
plotter.plot_cross_plot(
                        x = clean_data[idx].values,
                        y = df_imputed[idx].values,
                        x_label = r'$ \rm Original$',
                        y_label = r'$ \rm Imputed$',
                        property = idx,
                        fig_size=(3, 2))

# %%
# performance metrics
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score
print(f'IDX {idx}')
print(f'RMSE: {root_mean_squared_error(clean_data[idx].values, df_imputed[idx].values):.2f}')
print(f'MAE: {mean_absolute_error(clean_data[idx].values, df_imputed[idx].values):.2f}')
print(f'R2: {r2_score(clean_data[idx].values, df_imputed[idx].values):.2f}')
# Out:
# IDX SA
# RMSE: 383.66
# MAE: 230.64
# R2: 0.29

# %% [markdown]
# #### Extra Tree Regressor

# %%
method = 'ExtraTreesRegressor'
model = IterativeImputer(estimator=ExtraTreesRegressor(n_estimators=20),
                                 random_state=0,
                                 max_iter=500)

IMPUTER = Imputation(data=clean_data_with_NaN, columns=desired_columns, model=model, method=method)

df_imputed = IMPUTER.impute_data(split_data=False)
# Out:
# 2024-02-15 11:51:15.906 | INFO     | cdi.dataPreprocessing:impute:100 - Database path:         SA    DG    %N     %O    %S    CD  CONC    CAP
# 152    NaN  1.01  1.46  11.94  1.14   0.5   6.0  378.0
# 153  308.8  1.01  1.46  11.94  1.14   1.0   6.0  352.0
# 154    NaN  1.01  1.46  11.94  1.14   2.0   6.0  325.0
# 155  308.8  1.01  1.46  11.94  1.14   5.0   6.0  308.0
# 156    NaN  1.01  1.46  11.94  1.14  10.0   6.0  292.0
# 2024-02-15 11:51:15.907 | INFO     | cdi.dataPreprocessing:impute:101 - ML method: ExtraTreesRegressor
#
# 2024-02-15 11:51:15.907 | INFO     | cdi.dataPreprocessing:impute:103 - Number of data points: 159
# 2024-02-15 11:51:15.907 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "SA": 107
# 2024-02-15 11:51:15.908 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "DG": 0
# 2024-02-15 11:51:15.908 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%N": 0
# 2024-02-15 11:51:15.908 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%O": 0
# 2024-02-15 11:51:15.908 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "%S": 0
# 2024-02-15 11:51:15.909 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CD": 0
# 2024-02-15 11:51:15.909 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CONC": 0
# 2024-02-15 11:51:15.909 | WARNING  | cdi.dataPreprocessing:impute:106 - Number of missing values in "CAP": 0
# [IterativeImputer] Early stopping criterion not reached.
# 2024-02-15 11:51:40.889 | SUCCESS  | cdi.dataPreprocessing:impute:120 - Final Data shape is (159, 8).
# 2024-02-15 11:51:40.889 | SUCCESS  | cdi.dataPreprocessing:impute:121 - Imputation completed using ExtraTreesRegressor model.

# %%
# check if the imputed data is the same as the original data
# plot distribution of the original and imputed data

plotter.plot_kde(
                data = [clean_data[idx].values, df_imputed[idx].values],
                labels = [r'$ \rm Original$', r'$ \rm Imputed$'],
                colors = ['C10', 'C1'],
                property = idx,
                fig_size=(3, 2))

# %%
# # plt crossplot
plotter.plot_cross_plot(
                        x = clean_data[idx].values,
                        y = df_imputed[idx].values,
                        x_label = r'$ \rm Original$',
                        y_label = r'$ \rm Imputed$',
                        property = idx,
                        fig_size=(3, 2))

# %%
# performance metrics
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, r2_score
print(f'IDX {idx}')
print(f'RMSE: {root_mean_squared_error(clean_data[idx].values, df_imputed[idx].values):.2f}')
print(f'MAE: {mean_absolute_error(clean_data[idx].values, df_imputed[idx].values):.2f}')
print(f'R2: {r2_score(clean_data[idx].values, df_imputed[idx].values):.2f}')
# Out:
# IDX SA
# RMSE: 112.83
# MAE: 43.59
# R2: 0.94
